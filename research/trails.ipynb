# %%
import gdown

# %%
import sys
print(sys.executable)
# Out:
# c:\PROJECTS\End_to_end_Kidney_Disease_Classification_Deep_learning_project\venv\Scripts\python.exe

# %%
url ="https://drive.google.com/drive/folders/11cOMCoUfGqOFS2vkMa4x_IDZygSJ6bzR?usp=sharing"

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'drive',
#  'folders',
#  '11cOMCoUfGqOFS2vkMa4x_IDZygSJ6bzR?usp=drive_link']

# %%
url.split("/")[-1]
# Out:
# '11cOMCoUfGqOFS2vkMa4x_IDZygSJ6bzR?usp=drive_link'

# %%
file_id = "11cOMCoUfGqOFS2vkMa4x_IDZygSJ6bzR"

# %%
gdown.download(
    url,
    "Kidney-CT-Scan-data.zip",
    quiet=False,
    use_cookies=True
)
# Out:
# Downloading...
# From: https://drive.google.com/drive/folders/11cOMCoUfGqOFS2vkMa4x_IDZygSJ6bzR?usp=sharing
# To: c:\PROJECTS\End_to_end_Kidney_Disease_Classification_Deep_learning_project\research\Kidney-CT-Scan-data.zip
# 1.38MB [00:00, 23.5MB/s]
# 'Kidney-CT-Scan-data.zip'
